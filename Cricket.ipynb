# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('batting_averages.csv')
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %% [markdown]
# # ******** DOING EXPLORATORY DATA ANALYSIS AND DATA CLEANING *********

# %% [markdown]
# # Checking Summary of Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  62 non-null     object
#  1   Span    62 non-null     object
#  2   Mat     62 non-null     int64
#  3   Inns    62 non-null     int64
#  4   NO      62 non-null     int64
#  5   Runs    62 non-null     int64
#  6   HS      62 non-null     object
#  7   Ave     62 non-null     float64
#  8   BF      62 non-null     object
#  9   SR      62 non-null     object
#  10  100     62 non-null     int64
#  11  50      62 non-null     int64
#  12  0       62 non-null     object
#  13  4s      62 non-null     object
#  14  6s      62 non-null     object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 7.4+ KB

# %% [markdown]
# # Checking NULL values

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# 4s        0
# 6s        0
# dtype: int64

# %% [markdown]
# # Checking Duplicate Data

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Getting Summary Statistics of Dataframe

# %%
df.describe()
# Out:
#               Mat        Inns         NO          Runs        Ave        100  \
# count   62.000000   62.000000  62.000000     62.000000  62.000000  62.000000
# mean    78.693548  133.467742  13.919355   6332.580645  53.815484  19.080645
# std     52.035482   88.593697  11.374833   4116.130956   7.187252  12.693484
# min     12.000000   20.000000   1.000000    990.000000  48.000000   1.000000
# 25%     23.250000   40.250000   5.000000   2206.500000  49.660000   7.000000
# 50%     79.000000  131.500000  12.000000   6192.000000  51.950000  19.000000
# 75%    117.750000  199.500000  19.000000   9156.750000  56.677500  28.750000
# max    200.000000  329.000000  49.000000  15921.000000  99.940000  51.000000
#
#               50
# count  62.000000
# mean   28.225806
# std    19.111767
# min     3.000000
# 25%    10.000000
# 50%    28.000000
# 75%    42.500000
# max    68.000000

# %% [markdown]
# # Plotting summary statistics for better understanding

# %%
desc = df.describe()

desc.plot(kind='bar')
plt.title("Summary Statistics")
plt.ylabel("Values")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Renaming columns for better understanding

# %%
df = df.rename(columns={'Mat':'Matches','Inns':'Innings','NO':'Not_Outs','HS':'Highest_Score','Ave':'Average','SR':'Strike_Rate','BF':'Balls_Faced'})
df
# Out:
#                Player       Span  Matches  Innings  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52       80        10  6996
# 1    PHKD Mendis (SL)  2022-2025       12       21         2  1184
# 2      AC Voges (AUS)  2015-2016       20       31         7  1485
# 3     RG Pollock (SA)  1963-1970       23       41         4  2256
# 4     GA Headley (WI)  1930-1954       22       40         4  2190
# ..                ...        ...      ...      ...       ...   ...
# 57   KD Walters (AUS)  1965-1981       74      125        14  5357
# 58  GC Smith (ICC/SA)  2002-2014      117      205        13  9265
# 59  WH Ponsford (AUS)  1924-1934       29       48         4  2122
# 60    SJ McCabe (AUS)  1930-1938       39       62         5  2748
# 61   DR Jardine (ENG)  1928-1934       22       33         6  1296
#
#    Highest_Score  Average Balls_Faced Strike_Rate  100  50   0    4s  6s
# 0            334    99.94       9800+       58.60   29  13   7  626+   6
# ...

# %% [markdown]
# # Split 'Span' column into two seperate columns 'Start_Date' & 'End_Date'

# %%
df['Start_Year'] = df['Span'].str.split('-').str[0]
df['End_Year'] = df['Span'].str.split('-').str[1]
df.head(5)
# Out:
#              Player       Span  Matches  Innings  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948       52       80        10  6996
# 1  PHKD Mendis (SL)  2022-2025       12       21         2  1184
# 2    AC Voges (AUS)  2015-2016       20       31         7  1485
# 3   RG Pollock (SA)  1963-1970       23       41         4  2256
# 4   GA Headley (WI)  1930-1954       22       40         4  2190
#
#   Highest_Score  Average Balls_Faced Strike_Rate  100  50  0    4s  6s  \
# 0           334    99.94       9800+       58.60   29  13  7  626+   6
# 1          182*    62.31        1839       64.38    5   4  -   123  23
# 2          269*    61.87        2667       55.68    5   4  2   186   5
# 3           274    60.97       1707+       54.48    7  11  1  246+  11
# 4          270*    60.83        416+       56.00   10   5  2  104+   1
#
#   Start_Year End_Year
# 0       1928     1948
# 1       2022     2025
# 2       2015     2016
# 3       1963     1970
# 4       1930     1954

# %% [markdown]
# # Delete 'Span' Column

# %%
df = df.drop(columns=['Span'])
df
# Out:
#                Player  Matches  Innings  Not_Outs  Runs Highest_Score  \
# 0    DG Bradman (AUS)       52       80        10  6996           334
# 1    PHKD Mendis (SL)       12       21         2  1184          182*
# 2      AC Voges (AUS)       20       31         7  1485          269*
# 3     RG Pollock (SA)       23       41         4  2256           274
# 4     GA Headley (WI)       22       40         4  2190          270*
# ..                ...      ...      ...       ...   ...           ...
# 57   KD Walters (AUS)       74      125        14  5357           250
# 58  GC Smith (ICC/SA)      117      205        13  9265           277
# 59  WH Ponsford (AUS)       29       48         4  2122           266
# 60    SJ McCabe (AUS)       39       62         5  2748           232
# 61   DR Jardine (ENG)       22       33         6  1296           127
#
#     Average Balls_Faced Strike_Rate  100  50   0    4s  6s Start_Year End_Year
# ...

# %% [markdown]
# # Remove Country from the players name to new coloumn 'Country'

# %%
df['Country'] = df['Player'].str.split('(').str[1]
df['Country'] = df['Country'].str.split(')').str[0]
df['Player'] = df['Player'].str.split('(').str[0]
df
# Out:
#           Player  Matches  Innings  Not_Outs  Runs Highest_Score  Average  \
# 0    DG Bradman        52       80        10  6996           334    99.94
# 1   PHKD Mendis        12       21         2  1184          182*    62.31
# 2      AC Voges        20       31         7  1485          269*    61.87
# 3    RG Pollock        23       41         4  2256           274    60.97
# 4    GA Headley        22       40         4  2190          270*    60.83
# ..           ...      ...      ...       ...   ...           ...      ...
# 57   KD Walters        74      125        14  5357           250    48.26
# 58     GC Smith       117      205        13  9265           277    48.25
# 59  WH Ponsford        29       48         4  2122           266    48.22
# 60    SJ McCabe        39       62         5  2748           232    48.21
# 61   DR Jardine        22       33         6  1296           127    48.00
#
#    Balls_Faced Strike_Rate  100  50   0    4s  6s Start_Year End_Year Country
# ...

# %% [markdown]
# # Dealing with Datatypes of the columns

# %%
df.dtypes
# Out:
# Player            object
# Matches            int64
# Innings            int64
# Not_Outs           int64
# Runs               int64
# Highest_Score     object
# Average          float64
# Balls_Faced       object
# Strike_Rate       object
# 100                int64
# 50                 int64
# 0                 object
# 4s                object
# 6s                object
# Start_Year        object
# End_Year          object
# Country           object
# dtype: object

# %%
df = df.astype({'Start_Year':'int', 'End_Year':'int'})
df.dtypes
# Out:
# Player            object
# Matches            int64
# Innings            int64
# Not_Outs           int64
# Runs               int64
# Highest_Score     object
# Average          float64
# Balls_Faced       object
# Strike_Rate       object
# 100                int64
# 50                 int64
# 0                 object
# 4s                object
# 6s                object
# Start_Year         int64
# End_Year           int64
# Country           object
# dtype: object

# %% [markdown]
# # Rename the Column '100','50','0','4s','6s'.

# %%
df = df.rename(columns = {'100':'Centuries','50':'Fifties','0':'Ducks','4s':'Fours','6s':'Sixes'})
df
# Out:
#           Player  Matches  Innings  Not_Outs  Runs Highest_Score  Average  \
# 0    DG Bradman        52       80        10  6996           334    99.94
# 1   PHKD Mendis        12       21         2  1184          182*    62.31
# 2      AC Voges        20       31         7  1485          269*    61.87
# 3    RG Pollock        23       41         4  2256           274    60.97
# 4    GA Headley        22       40         4  2190          270*    60.83
# ..           ...      ...      ...       ...   ...           ...      ...
# 57   KD Walters        74      125        14  5357           250    48.26
# 58     GC Smith       117      205        13  9265           277    48.25
# 59  WH Ponsford        29       48         4  2122           266    48.22
# 60    SJ McCabe        39       62         5  2748           232    48.21
# 61   DR Jardine        22       33         6  1296           127    48.00
#
#    Balls_Faced Strike_Rate  Centuries  Fifties Ducks Fours Sixes  Start_Year  \
# ...

# %% [markdown]
# # Drop record for 'GA Headley'

# %%
df[df['Player'].str.contains('GA Headley')]
# Out:
#         Player       Span  Matches  Innings  Not_Outs  Runs Highest_Score  \
# 4  GA Headley   1930-1954       22       40         4  2190          270*
#
#    Average Balls_Faced Strike_Rate  Centuries  Fifties Ducks Fours Sixes  \
# 4    60.83        416+       56.00         10        5     2  104+     1
#
#    Start_Year  End_Year Country
# 4        1930      1954      WI

# %%
df = df.drop(4,axis=0)
df
# Out:
#           Player       Span  Matches  Innings  Not_Outs  Runs Highest_Score  \
# 0    DG Bradman   1928-1948       52       80        10  6996           334
# 1   PHKD Mendis   2022-2025       12       21         2  1184          182*
# 2      AC Voges   2015-2016       20       31         7  1485          269*
# 3    RG Pollock   1963-1970       23       41         4  2256           274
# 5   H Sutcliffe   1924-1935       54       84         9  4555           194
# ..           ...        ...      ...      ...       ...   ...           ...
# 57   KD Walters   1965-1981       74      125        14  5357           250
# 58     GC Smith   2002-2014      117      205        13  9265           277
# 59  WH Ponsford   1924-1934       29       48         4  2122           266
# 60    SJ McCabe   1930-1938       39       62         5  2748           232
# 61   DR Jardine   1928-1934       22       33         6  1296           127
#
# ...

# %% [markdown]
# # ************* SOLVING DATA ANALYISIS QUESTIONS *************

# %% [markdown]
# # 1. Find out the carrier length for each player

# %%
# Convert year columns to integers (handling non-numeric values)
df['Start_Year'] = pd.to_numeric(df['Start_Year'], errors='coerce')
df['End_Year'] = pd.to_numeric(df['End_Year'], errors='coerce')

# Now calculate the difference
df['Carrier_Length'] = df['End_Year'] - df['Start_Year']

# Optional: Fill NA values (if conversion failed)
df['Carrier_Length'] = df['Carrier_Length'].fillna(0)
df
# Out:
#           Player  Matches  Innings  Not_Outs  Runs Highest_Score  Average  \
# 0    DG Bradman        52       80        10  6996           334    99.94
# 2      AC Voges        20       31         7  1485          269*    61.87
# 3    RG Pollock        23       41         4  2256           274    60.97
# 4    GA Headley        22       40         4  2190          270*    60.83
# 5   H Sutcliffe        54       84         9  4555           194    60.73
# ..           ...      ...      ...       ...   ...           ...      ...
# 57   KD Walters        74      125        14  5357           250    48.26
# 58     GC Smith       117      205        13  9265           277    48.25
# 59  WH Ponsford        29       48         4  2122           266    48.22
# 60    SJ McCabe        39       62         5  2748           232    48.21
# 61   DR Jardine        22       33         6  1296           127    48.00
#
#    Balls_Faced  Strike_Rate  Centuries  ...  Ducks Fours  Sixes  Start_Year  \
# ...

# %% [markdown]
# # 2. Find Top 5 Performers

# %%
df.sort_values(by='Runs', ascending = False).head(5)
# Out:
#            Player       Span  Matches  Innings  Not_Outs   Runs Highest_Score  \
# 24  SR Tendulkar   1989-2013      200      329        33  15921          248*
# 31    RT Ponting   1995-2012      168      287        29  13378           257
# 17     JH Kallis   1995-2013      166      280        40  13289           224
# 28      R Dravid   1996-2012      164      286        32  13288           270
# 38       JE Root   2012-2024      152      278        23  12972           262
#
#     Average Balls_Faced Strike_Rate  Centuries  Fifties Ducks  Fours Sixes  \
# 24    53.78      29437+       54.04         51       68    14  2058+    69
# 31    51.85       22782       58.72         41       62    17   1509    73
# 17    55.37       28903       45.97         45       58    16   1488    97
# 28    52.31       31258       42.51         36       63     8   1654    21
# 38    50.87       22568       57.47         36       65    13   1394    45
#
# ...

# %% [markdown]
# # 3. Find the Players with Average over 50

# %%
df[df['Average'] > 50]
# Out:
#               Player       Span  Matches  Innings  Not_Outs   Runs  \
# 0        DG Bradman   1928-1948       52       80        10   6996
# 1       PHKD Mendis   2022-2025       12       21         2   1184
# 2          AC Voges   2015-2016       20       31         7   1485
# 3        RG Pollock   1963-1970       23       41         4   2256
# 5       H Sutcliffe   1924-1935       54       84         9   4555
# 6         E Paynter   1931-1939       20       31         5   1540
# 7     KF Barrington   1955-1968       82      131        15   6806
# 8         ED Weekes   1948-1958       48       81         5   4455
# 9          HC Brook   2022-2024       24       40         1   2281
# 10       WR Hammond   1927-1947       85      140        16   7249
# 11        GS Sobers   1954-1974       93      160        21   8032
# 12    KC Sangakkara   2000-2015      134      233        17  12400
# 13         JB Hobbs   1908-1930       61      102         7   5410
# ...

# %% [markdown]
# # 4. Players with Highest Centuries

# %%
df[['Player','Centuries']].sort_values(by='Centuries', ascending=False).head(10)
# Out:
#                Player  Centuries
# 24      SR Tendulkar          51
# 17         JH Kallis          45
# 31        RT Ponting          41
# 12     KC Sangakkara          38
# 38           JE Root          36
# 28          R Dravid          36
# 14         SPD Smith          36
# 45  DPMD Jayawardene          34
# 36       SM Gavaskar          34
# 30       Younis Khan          34

# %% [markdown]
# # 5. What is the average career length per country?

# %%
df[['Country','Carrier_Length']].groupby('Country').agg({'Carrier_Length':'mean'})
# Out:
#          Carrier_Length
# Country
# AUS           12.933333
# ENG           13.000000
# ICC/IND       14.000000
# ICC/PAK       15.000000
# ICC/SA        15.000000
# ICC/WI        16.000000
# IND           11.000000
# NZ            14.000000
# PAK           10.200000
# SA            12.400000
# SL            11.750000
# WI            14.285714
# ZIM           10.000000

# %% [markdown]
# # 6. Which player has the highest batting average?

# %%
df[['Player','Average']].sort_values('Average', ascending=False).head(1)
# Out:
#         Player  Average
# 0  DG Bradman     99.94

# %% [markdown]
# # 7. Which players have the highest strike rates?

# %%
df[['Player','Strike_Rate']].sort_values('Strike_Rate', ascending=False).head(1)
# Out:
#       Player Strike_Rate
# 9  HC Brook        88.37

# %% [markdown]
# # 8. What is the distribution of centuries per player?

# %%
# Group players by the number of 100s and count how many fall into each group
hundreds_distribution = df['Centuries'].value_counts().sort_index()

# Plotting the distribution
plt.figure(figsize=(10, 6))
hundreds_distribution.plot(kind='bar', color='skyblue')
plt.title("Distribution of 100s Scored by Players")
plt.xlabel("Number of 100s")
plt.ylabel("Number of Players")
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. What is the ratio of 50s to 100s for each player?

# %%
df['50_to_100_ratio'] = df['Fifties'] / df['Centuries'].replace(0, pd.NA)

# Display relevant columns
df[['Player', 'Centuries', 'Fifties', '50_to_100_ratio']].sort_values(by='50_to_100_ratio', ascending=False)
# Out:
#           Player  Centuries  Fifties  50_to_100_ratio
# 61   DR Jardine           1       10        10.000000
# 32      J Ryder           3        9         3.000000
# 52     KC Bland           3        9         3.000000
# 53   B Mitchell           8       21         2.625000
# 26  YBK Jaiswal           4       10         2.500000
# ..           ...        ...      ...              ...
# 1   PHKD Mendis           5        4         0.800000
# 50     Abid Ali           4        3         0.750000
# 48      CP Mead           4        3         0.750000
# 21    VG Kambli           4        3         0.750000
# 0    DG Bradman          29       13         0.448276
#
# [61 rows x 4 columns]

# %% [markdown]
# # 10. Which players have the most consistent batting average over long careers.

# %%
# Convert 'Zeros' column to numeric if needed
df['Ducks'] = pd.to_numeric(df['Ducks'], errors='coerce')

# Filter players with careers longer than 10 years
long_career_df = df[df['Carrier_Length'] > 10]

# Sort by highest average, and lowest ducks (optional consistency proxy)
consistent_players = long_career_df.sort_values(by=['Average', 'Ducks'], ascending=[False, True])

# Display top players
consistent_players[['Player', 'Carrier_Length', 'Average', 'Ducks']].head(10)
# Out:
#             Player  Carrier_Length  Average  Ducks
# 0      DG Bradman               20    99.94      7
# 4      GA Headley               24    60.83      2
# 5     H Sutcliffe               11    60.73      2
# 7   KF Barrington               13    58.67      5
# 10     WR Hammond               20    58.45      4
# 11      GS Sobers               20    57.78     12
# 12  KC Sangakkara               15    57.40     11
# 13       JB Hobbs               22    56.94      4
# 14      SPD Smith               15    56.74     11
# 15     CL Walcott               12    56.68      1

# %% [markdown]
# # 11. Which players have scored the most boundaries

# %%
df['Fours'] = pd.to_numeric(df['Fours'].astype(str).str.replace('+', '', regex=False), errors='coerce')
df['Sixes'] = pd.to_numeric(df['Sixes'].astype(str).str.replace('+', '', regex=False), errors='coerce')


df['Total_Boundaries'] = df['Fours'] + df['Sixes']

most_boundaries = df[['Player', 'Fours', 'Sixes', 'Total_Boundaries']].sort_values(by='Total_Boundaries', ascending=False)


most_boundaries.head(10)
# Out:
#                Player  Fours  Sixes  Total_Boundaries
# 24      SR Tendulkar    2058     69              2127
# 28          R Dravid    1654     21              1675
# 25           BC Lara    1559     88              1647
# 17         JH Kallis    1488     97              1585
# 31        RT Ponting    1509     73              1582
# 12     KC Sangakkara    1491     51              1542
# 45  DPMD Jayawardene    1387     61              1448
# 38           JE Root    1394     45              1439
# 49          V Sehwag    1233     91              1324
# 35     S Chanderpaul    1285     36              1321

# %% [markdown]
# # 12. Who has the highest percentage of not outs per innings?

# %%
df['Percentage'] = (df['Not_Outs'] / df['Innings']) * 100

percentage_not_outs = df[['Player', 'Not_Outs', 'Innings', 'Percentage']].sort_values(by='Percentage', ascending=False)

percentage_not_outs.head(10)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#              Player  Not_Outs  Innings  Percentage
# 2         AC Voges          7       31   22.580645
# 61      DR Jardine          6       33   18.181818
# 37        SR Waugh         46      260   17.692308
# 35   S Chanderpaul         49      280   17.500000
# 20        CA Davis          5       29   17.241379
# 33        A Flower         19      112   16.964286
# 41       AR Border         44      265   16.603774
# 6        E Paynter          5       31   16.129032
# 32         J Ryder          5       32   15.625000
# 55  TT Samaraweera         20      132   15.151515

# %% [markdown]
# # 13. Which decade produced the most high-average player?

# %%
# Step 1: Create 'Decade' column
df['Decade'] = (df['Start_Year'] / 10) * 10

# Step 2: Filter high-average players
high_avg_df = df[df['Average'] > 50]

# Step 3: Count how many high-average players started in each decade
decade_counts = high_avg_df['Decade'].vsort_values(ascending=False).head(10)

# Display
decade_counts_df
# Out:
#     Decade  High_Avg_Player_Count
# 8     1990                      9
# 1     1920                      5
# 2     1930                      5
# 6     1970                      5
# 9     2000                      4
# 10    2010                      4
# 11    2020                      3
# 3     1940                      2
# 4     1950                      2
# 5     1960                      2
# 7     1980                      2
# 0     1900                      1

# %% [markdown]
# # 14. Is there a correlation between strike rate and batting average?

# %%
# Step 1: Convert Strike_Rate to numeric
df['Strike_Rate'] = pd.to_numeric(df['Strike_Rate'], errors='coerce')

# Step 2: Drop rows with missing values in either Strike_Rate or Average
clean_df = df.dropna(subset=['Strike_Rate', 'Average'])

# Step 3: Compute correlation
correlation = clean_df['Strike_Rate'].corr(clean_df['Average'])
correlation

plt.figure(figsize=(8,6))
plt.scatter(clean_df['Strike_Rate'], clean_df['Average'], alpha=0.7, color='green')
plt.title('Correlation Between Strike Rate and Batting Average')
plt.xlabel('Strike Rate')
plt.ylabel('Batting Average')
plt.grid(True)
plt.show()

# %% [markdown]
# # 15. What’s the average number of matches per year per player?

# %%
# Calculate average matches per year
df['Carrier_Length'] = df['End_Year'] - df['Start_Year']
df['Matches_per_Year'] = df['Matches'] / df['Carrier_Length']

# View top players with highest match frequency
df[['Player', 'Matches', 'Carrier_Length', 'Matches_per_Year']].sort_values(by='Matches_per_Year', ascending=False)
# Out:
#              Player  Matches  Carrier_Length  Matches_per_Year
# 2         AC Voges        20               1         20.000000
# 38         JE Root       152              12         12.666667
# 9         HC Brook        24               2         12.000000
# 51       MJ Clarke       115              11         10.454545
# 28        R Dravid       164              16         10.250000
# ..              ...      ...             ...               ...
# 53      B Mitchell        42              20          2.100000
# 18    GE Tyldesley        14               8          1.750000
# 54  Hon.FS Jackson        20              12          1.666667
# 48         CP Mead        17              17          1.000000
# 4       GA Headley        22              24          0.916667
#
# [62 rows x 4 columns]

# %% [markdown]
# # 16. Which country has the highest average player strike rate?

# %%
avg_strike_rate = df.groupby('Country').agg({'Strike_Rate':'mean'})
ans = avg_strike_rate.sort_values(by='Strike_Rate', ascending= False).head(10)
ans
# Out:
#          Strike_Rate
# Country
# ICC/IND    62.370000
# ICC/WI     60.510000
# IND        55.627500
# ICC/PAK    54.020000
# ICC/SA     52.820000
# NZ         51.780000
# AUS        51.768000
# SL         50.853333
# WI         49.716667
# PAK        49.664000

# %% [markdown]
# # 17. How many players have a highest score above 200?

# %%
# Step 1: Clean 'Highest_Score' to remove '*' and convert to numeric
df['Highest_Score_Clean'] = pd.to_numeric(df['Highest_Score'].astype(str).str.replace('*', '', regex=False), errors='coerce')

# Step 2: Filter players who scored 200 or more
high_scorers_200 = df[df['Highest_Score_Clean'] >= 200]

# Step 3: Count them
num_high_scorers = high_scorers_200.shape[0]
print(f"Number of players who scored 200 or more: {num_high_scorers}")
# Out:
# Number of players who scored 200 or more: 52
